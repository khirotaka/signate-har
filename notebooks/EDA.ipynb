# %%
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/khirotaka/PycharmProjects/signate-har/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = catalog.datasets.har_train.load()

# %%
df.head()
# Out:
#    id  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0   0           0.273049           0.029455          -0.108114
# 1   2           0.252055          -0.035983          -0.128469
# 2   3           0.283767          -0.016931          -0.109087
# 3   4           0.259078          -0.016357          -0.114833
# 4   5           0.273949          -0.021795          -0.117436
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0          0.169687         -0.010238         -0.328502          0.124848
# 1         -0.436843         -0.153635         -0.223741         -0.450711
# 2         -0.988980         -0.989567         -0.986512         -0.989212
# 3         -0.993216         -0.992404         -0.989001         -0.993880
# 4         -0.995829         -0.984692         -0.986809         -0.996566
#
#    tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  ...  fBodyBodyGyroJerkMag-skewness()  \
# ...

# %%
targets = df["activity"]
data = df.drop("activity", axis=1)

# %%
targets.unique()
# Out:
# array(['WALKING_DOWNSTAIRS', 'WALKING', 'LAYING', 'STANDING',
#        'WALKING_UPSTAIRS', 'SITTING'], dtype=object)

# %%
fig = plt.figure(figsize=(10, 8), facecolor="white")
ax1 = fig.add_subplot(3, 1, 1)
sns.distplot(data["tBodyAcc-mean()-X"], ax=ax1)

ax2 = fig.add_subplot(3, 1, 2)
sns.distplot(data["tBodyAcc-mean()-Y"], ax=ax2)

ax3 = fig.add_subplot(3, 1, 3)
sns.distplot(data["tBodyAcc-mean()-Z"], ax=ax3)

fig.show()

# %%
fig = plt.figure(figsize=(10, 8), facecolor="white")
ax1 = fig.add_subplot(3, 1, 1)
sns.distplot(data["tBodyAcc-std()-X"], ax=ax1)

ax2 = fig.add_subplot(3, 1, 2)
sns.distplot(data["tBodyAcc-std()-Y"], ax=ax2)

ax3 = fig.add_subplot(3, 1, 3)
sns.distplot(data["tBodyAcc-std()-Z"], ax=ax3)

fig.show()

# %%
g1 = sns.jointplot(data["tBodyAcc-mean()-X"], data["tGravityAcc-mean()-X"], kind="reg")

g2 = sns.jointplot(data["tBodyAcc-std()-X"], data["tGravityAcc-std()-X"], kind="reg")
